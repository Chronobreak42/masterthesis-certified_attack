# %% [markdown]
# cert_config_1:cert_confg_nSamplesEval10000_nSPreEval1000_pfPlusAd0.01_pfMinAdj0.6_pfPlusAtt0_pfMinAtt0_batchSize20_alpha0.01 partlyDrawnNodes:True

# %%
cert_config_2:cert_confg_nSamplesEval10000_nSPreEval1000_pfPlusAd0.02_pfMinAdj0.6_pfPlusAtt0_pfMinAtt0_batchSize20_alpha0.01 partlyDrawnNodes:True

# %%
cert_config_2:cert_confg_nSamplesEval10000_nSPreEval1000_pfPlusAd0.05_pfMinAdj0.6_pfPlusAtt0_pfMinAtt0_batchSize20_alpha0.01 partlyDrawnNodes:True
